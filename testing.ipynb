# %% [markdown]
# <a href="https://colab.research.google.com/github/pereram/Research_with_SmolLM-/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('abc"')
# Out:
# abc"
